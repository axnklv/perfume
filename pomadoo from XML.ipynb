# %%
import xml.etree.ElementTree as ET
import requests
import pandas as pd

# %%
class XML2DataFrame:
    def __init__(self, xml_data):
        self.root = ET.XML(xml_data)

    def parse_root(self, root):
        return [self.parse_element(child) for child in iter(root)]

    def parse_element(self, element, parsed=None):
        if parsed is None:
            parsed = dict()
        for key in element.keys():
            parsed[key] = element.attrib.get(key)
        if element.text:
            m = {
                'Пол':'sex',
                'Год выпуска':'start_year',
                'Объем':'vol',
                'Тестер':'tester',
                'Семейство':'family',
                'Пробник':'probnik',
                }
            if element.tag == 'param':
                if element.attrib.get('name') == 'Объем':
                    try:
                        ml = ' '+str(element.attrib.get('unit'))
                    except:
                        ml = ''
                    parsed[m[element.attrib.get('name')]] = element.text+ml
                else:
                    parsed[m[element.attrib.get('name')]] = element.text
            else:
                parsed[element.tag] = element.text
        for child in list(element):
            self.parse_element(child, parsed)
        return parsed

    def process_data(self):
        structure_data = self.parse_root(self.root)
        return pd.DataFrame(structure_data)

# %%
# %%time
xml2df = XML2DataFrame(requests.get('https://pompadoo.ru/catalog/yml/').content)
# Out:
# Wall time: 13.5 s

# %%
#получаем поле offers
xml2df.root = xml2df.root[0][5]

# %%
xml_df = xml2df.process_data()

# %%
xml_df.head(10)
# Out:
#   available categoryId country_of_origin cpa currencyId delivery description  \
# 0      true          8           Франция   1        RUR     true         NaN
# 1      true          8           Франция   1        RUR     true         NaN
# 2      true          8           Франция   1        RUR     true         NaN
# 3      true          8           Франция   1        RUR     true         NaN
# 4      true          8            Япония   1        RUR     true         NaN
# 5      true          8           Франция   1        RUR     true         NaN
# 6      true          8           Франция   1        RUR     true         NaN
# 7      true          8           Франция   1        RUR     true         NaN
# 8      true          8          Германия   1        RUR     true         NaN
# 9      true         14           Франция   1        RUR     true         NaN
#
#                  family     id model  ...   probnik      sex start_year  \
# 0   цветочные фруктовые  10148    40  ...       NaN  Женский       2015
# 1   цветочные фруктовые   8991    75  ...       NaN  Женский       2015
# 2  восточные цитрусовые   4992    35  ...       NaN  Женский       2012
# 3  восточные цитрусовые   8182    50  ...       NaN  Женский       2012
# 4                   NaN  11126    80  ...       NaN  Женский        NaN
# 5   восточные цветочные   9375    30  ...       NaN  Женский       2012
# 6   восточные цветочные  11203    50  ...       NaN  Женский       2012
# 7   восточные цветочные   8650    90  ...       NaN  Женский       2012
# 8   цветочные фруктовые   5648    75  ...       NaN  Женский       2010
# 9      древесные пряные   6166     2  ...        Да  Унисекс       2009
#
#    store tester unit                                          url  \
# 0  false    NaN   мл  https://pompadoo.ru/product/4725/?sku=10148
# 1  false     Да   мл   https://pompadoo.ru/product/4725/?sku=8991
# 2  false    NaN   мл   https://pompadoo.ru/product/2801/?sku=4992
# 3  false    NaN   мл   https://pompadoo.ru/product/2801/?sku=8182
# 4  false    NaN   мл  https://pompadoo.ru/product/5549/?sku=11126
# 5  false    NaN   мл   https://pompadoo.ru/product/4608/?sku=9375
# 6  false    NaN   мл  https://pompadoo.ru/product/4608/?sku=11203
# 7  false     Да   мл   https://pompadoo.ru/product/4608/?sku=8650
# 8  false     Да   мл   https://pompadoo.ru/product/3191/?sku=5648
# 9  false    NaN   мл   https://pompadoo.ru/product/3489/?sku=6166
#
#                vendor vendorCode    vol
# 0            Givenchy       4725  40 мл
# 1            Givenchy       4725  75 мл
# 2              Chanel       2801  35 мл
# 3              Chanel       2801  50 мл
# 4   Masaki Matsushima       5549  80 мл
# 5  Yves Saint Laurent       4608  30 мл
# 6  Yves Saint Laurent       4608  50 мл
# 7  Yves Saint Laurent       4608  90 мл
# 8           Hugo Boss       3191  75 мл
# 9             Montale       3489   2 мл
#
# [10 rows x 26 columns]

# %%
xml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 26 columns):
# available            4760 non-null object
# categoryId           4760 non-null object
# country_of_origin    4478 non-null object
# cpa                  4760 non-null object
# currencyId           4760 non-null object
# delivery             4760 non-null object
# description          31 non-null object
# family               4118 non-null object
# id                   4760 non-null object
# model                4760 non-null object
# name                 4760 non-null object
# offer                4760 non-null object
# oldprice             976 non-null object
# pickup               4760 non-null object
# picture              4760 non-null object
# price                4760 non-null object
# probnik              71 non-null object
# sex                  4760 non-null object
# start_year           4143 non-null object
# store                4760 non-null object
# tester               1159 non-null object
# unit                 4656 non-null object
# url                  4760 non-null object
# vendor               4760 non-null object
# vendorCode           4760 non-null object
# vol                  4656 non-null object
# dtypes: object(26)
# memory usage: 967.0+ KB

# %%
xml_df.fillna('-', inplace=True)

# %%
xml_df.head(10)
# Out:
#   available categoryId country_of_origin cpa currencyId delivery description  \
# 0      true          8           Франция   1        RUR     true           -
# 1      true          8           Франция   1        RUR     true           -
# 2      true          8           Франция   1        RUR     true           -
# 3      true          8           Франция   1        RUR     true           -
# 4      true          8            Япония   1        RUR     true           -
# 5      true          8           Франция   1        RUR     true           -
# 6      true          8           Франция   1        RUR     true           -
# 7      true          8           Франция   1        RUR     true           -
# 8      true          8          Германия   1        RUR     true           -
# 9      true         14           Франция   1        RUR     true           -
#
#                  family     id model  ...   probnik      sex start_year  \
# 0   цветочные фруктовые  10148    40  ...         -  Женский       2015
# 1   цветочные фруктовые   8991    75  ...         -  Женский       2015
# 2  восточные цитрусовые   4992    35  ...         -  Женский       2012
# 3  восточные цитрусовые   8182    50  ...         -  Женский       2012
# 4                     -  11126    80  ...         -  Женский          -
# 5   восточные цветочные   9375    30  ...         -  Женский       2012
# 6   восточные цветочные  11203    50  ...         -  Женский       2012
# 7   восточные цветочные   8650    90  ...         -  Женский       2012
# 8   цветочные фруктовые   5648    75  ...         -  Женский       2010
# 9      древесные пряные   6166     2  ...        Да  Унисекс       2009
#
#    store tester unit                                          url  \
# 0  false      -   мл  https://pompadoo.ru/product/4725/?sku=10148
# 1  false     Да   мл   https://pompadoo.ru/product/4725/?sku=8991
# 2  false      -   мл   https://pompadoo.ru/product/2801/?sku=4992
# 3  false      -   мл   https://pompadoo.ru/product/2801/?sku=8182
# 4  false      -   мл  https://pompadoo.ru/product/5549/?sku=11126
# 5  false      -   мл   https://pompadoo.ru/product/4608/?sku=9375
# 6  false      -   мл  https://pompadoo.ru/product/4608/?sku=11203
# 7  false     Да   мл   https://pompadoo.ru/product/4608/?sku=8650
# 8  false     Да   мл   https://pompadoo.ru/product/3191/?sku=5648
# 9  false      -   мл   https://pompadoo.ru/product/3489/?sku=6166
#
#                vendor vendorCode    vol
# 0            Givenchy       4725  40 мл
# 1            Givenchy       4725  75 мл
# 2              Chanel       2801  35 мл
# 3              Chanel       2801  50 мл
# 4   Masaki Matsushima       5549  80 мл
# 5  Yves Saint Laurent       4608  30 мл
# 6  Yves Saint Laurent       4608  50 мл
# 7  Yves Saint Laurent       4608  90 мл
# 8           Hugo Boss       3191  75 мл
# 9             Montale       3489   2 мл
#
# [10 rows x 26 columns]

# %%
vendors = xml_df.filter(['vendor'])

# %%
vendors['lowVendor'] = vendors.apply(lambda vendors: vendors['vendor'].lower(), axis=1)

# %%
vendors.head()
# Out:
#               vendor          lowVendor
# 0           Givenchy           givenchy
# 1           Givenchy           givenchy
# 2             Chanel             chanel
# 3             Chanel             chanel
# 4  Masaki Matsushima  masaki matsushima

# %%
vendors.to_csv('VendorsList.csv', index=False, encoding='utf-8')

# %%
brands = pd.read_csv('PerfumesList.csv')

# %%
brands['lowBrand'] = brands.apply(lambda brands: brands['name'].lower(), axis=1)

# %%
brands.head()
# Out:
#   letter                        name                                      url  \
# 0      A             A Bathing Ape              /designers/A-Bathing-Ape.html
# 1      A   A Beautiful Life Brands    /designers/A-Beautiful-Life-Brands.html
# 2      A             A Dozen Roses              /designers/A-Dozen-Roses.html
# 3      A                A La Russe                 /designers/A-La-Russe.html
# 4      A             A Lab on Fire              /designers/A-Lab-on-Fire.html
#
#                      lowBrand
# 0             a bathing ape
# 1   a beautiful life brands
# 2             a dozen roses
# 3                a la russe
# 4             a lab on fire

# %%
brands = brands.rename(columns={'name': 'brand'})

# %%
brands = brands[['brand', 'url', 'letter', 'lowBrand']]

# %%
brands.head()
# Out:
#                         brand                                      url letter  \
# 0             A Bathing Ape              /designers/A-Bathing-Ape.html      A
# 1   A Beautiful Life Brands    /designers/A-Beautiful-Life-Brands.html      A
# 2             A Dozen Roses              /designers/A-Dozen-Roses.html      A
# 3                A La Russe                 /designers/A-La-Russe.html      A
# 4             A Lab on Fire              /designers/A-Lab-on-Fire.html      A
#
#                      lowBrand
# 0             a bathing ape
# 1   a beautiful life brands
# 2             a dozen roses
# 3                a la russe
# 4             a lab on fire

# %%
brands.to_csv('BrandsList.csv', index=False, encoding='utf-8')

# %%
df = vendors.copy()

# %%
df['brand'] = brands['brand']
df['lowBrand'] = brands['lowBrand']
df['url'] = brands['url']

# %%
df.head()
# Out:
#               vendor          lowVendor                       brand  \
# 0           Givenchy           givenchy             A Bathing Ape
# 1           Givenchy           givenchy   A Beautiful Life Brands
# 2             Chanel             chanel             A Dozen Roses
# 3             Chanel             chanel                A La Russe
# 4  Masaki Matsushima  masaki matsushima             A Lab on Fire
#
#                      lowBrand                                      url
# 0             a bathing ape              /designers/A-Bathing-Ape.html
# 1   a beautiful life brands    /designers/A-Beautiful-Life-Brands.html
# 2             a dozen roses              /designers/A-Dozen-Roses.html
# 3                a la russe                 /designers/A-La-Russe.html
# 4             a lab on fire              /designers/A-Lab-on-Fire.html

# %%
unmatched = [set(df['lowVendor']) - set(df['lowBrand'])]

# %%
unmatched
# Out:
# [{'abercrombie & fitch',
#   'acqua di parma',
#   'adidas',
#   'agent provocateur',
#   'ajmal',
#   'al hamatt',
#   'al haramain',
#   'alaia',
#   'alexandre j.',
#   'alfred dunhill',
#   'alla pugacheva',
#   'amorino prive',
#   'amouage',
#   'amouroud',
#   'angel schlesser',
#   'anna sui',
#   'antonio banderas',
#   'aquolina',
#   'aramis',
#   'armand basi',
#   'armani',
#   'asgharali',
#   'atelier cologne',
#   'atkinsons',
#   'azzaro',
#   'baldessarini',
#   'baldinini',
#   'balenciaga cristobal',
#   'balmain',
#   'bamotte',
#   'banana republic',
#   'bebe',
#   'belletete',
#   'bentley',
#   'beyonce',
#   'bill blass',
#   'blumarine',
#   'boadicea the victorious',
#   'bottega veneta',
#   'boucheron',
#   'britney spears',
#   'bruno banani',
#   'burberry',
#   'bvlgari',
#   'byc moze',
#   'byredo',
#   'cacharel',
#   'cafe-cafe',
#   'caldion',
#   'calvin klein',
#   'canali',
#   'carner barcelona',
#   'carolina herrera',
#   'cartier',
#   'cerruti',
#   'chambor',
#   'chanel',
#   'chevignon',
#   'chloe',
#   'chopard',
#   'christian audigier',
#   'christian lacroix',
#   'christina aguilera',
#   'clinique',
#   'clive christian',
#   'coach',
#   'comme des garcons',
#   'costume national',
#   'courreges',
#   'courvoisier',
#   'creed',
#   'cristiano ronaldo',
#   'custo barcelona',
#   "d'orsay",
#   'david beckham',
#   'david yurman',
#   'davidoff',
#   'dear rose',
#   'diesel',
#   'dior',
#   'diptyque',
#   'dolce & gabbana',
#   'donna karan dkny',
#   'dsquared2',
#   'dupont s.t.',
#   'elie saab le parfum',
#   'elizabeth arden',
#   'ellen tracy',
#   'emanuel ungaro',
#   'emilio pucci',
#   'eon productions',
#   'ermenegildo zegna',
#   'escada',
#   'escentric molecules',
#   'esteban',
#   'estee lauder',
#   'ex nihilo',
#   'fendi',
#   'ferragamo salvatore',
#   'ferrari',
#   'ferre',
#   'fly falcone',
#   'francis kurkdjian',
#   'franck olivier',
#   'frapin',
#   'geoffrey beene',
#   'ghost',
#   'gian marco venturi',
#   'giulietta capuleti',
#   'givenchy',
#   'gloria vanderbilt',
#   'gucci',
#   'guerlain',
#   'guess',
#   'guy laroche',
#   'harajuku lovers',
#   'hermes',
#   'hollister',
#   'house of sillage',
#   'hugo boss',
#   'hummer',
#   'iceberg',
#   'issey miyake',
#   'jacques bogart',
#   'jean couturier',
#   'jean patou',
#   'jean paul gaultier',
#   'jennifer lopez',
#   'jessica mcclintock',
#   'jesus del pozo',
#   'jil sander',
#   'jimmy choo',
#   'jo malone',
#   'john galliano',
#   'john richmond',
#   'john varvatos',
#   'jose eisenberg',
#   'judith leiber',
#   'juicy couture',
#   'juliette has a gun',
#   'karl lagerfeld',
#   'katy perry',
#   'kenzo',
#   'kilian',
#   'korloff',
#   'krizia',
#   'la perla',
#   'lacoste',
#   'lady gaga',
#   'lalique',
#   'lancome',
#   'lanvin',
#   'laura biagiotti',
#   'lee cooper',
#   'lm parfums',
#   'loewe',
#   'lolita lempicka',
#   'louis feraud',
#   'm. micallef',
#   'madonna',
#   'mancera',
#   'mandarina duck',
#   'marc jacobs',
#   'masaki matsushima',
#   'mazzolari',
#   'memo',
#   'mexx',
#   'michael kors',
#   'miu miu',
#   'mont blanc',
#   'montale',
#   'moresque',
#   'moschino',
#   'myrurgia',
#   'narciso rodriguez',
#   'nasomatto',
#   'nina ricci',
#   'olfactive studio',
#   'orchid perfumes',
#   'paco rabanne',
#   'paloma picasso',
#   'pani walewska',
#   'parfums de marly',
#   "penhaligon's",
#   'playboy',
#   'porsche design',
#   'prada',
#   'princesse marina de bourbon',
#   'ralph lauren',
#   'ramon molvizar',
#   'remy latour',
#   'renegades',
#   'roberto cavalli',
#   'roberto verino',
#   'rochas',
#   'salvador dali',
#   'sarah jessica parker',
#   'schwarzkopf',
#   'sean john',
#   'serge lutens',
#   'shaik',
#   'shakira',
#   'shiseido',
#   'signature fragrances',
#   'simone cosac profumi',
#   'sisley',
#   'slava zaitsev',
#   'stefano ricci',
#   'stella mccartney',
#   'swarovski',
#   'tacchini',
#   'ted lapidus',
#   'the woods collection',
#   'thierry mugler',
#   'tiziana terenzi',
#   'tom ford',
#   'tommy hilfiger',
#   'tous',
#   'trussardi',
#   'ulric de varens',
#   'umbro',
#   'v canto',
#   'valentino',
#   'van cleef & arpels',
#   'vera wang',
#   'versace',
#   "victoria's secret",
#   'viktor & rolf',
#   'xerjoff',
#   'y.yamamoto',
#   'yves saint laurent',
#   'zadig & voltaire',
#   'zarkoperfume',
#   'zhirinovsky'}]

# %%
len(s)
# Out:
# 1

# %%
result_list = []
for x in unmatched:
    for y in list(x):
        result_list.append(y)
print(result_list)
# Out:
# ['geoffrey beene', 'jessica mcclintock', 'john galliano', 'asgharali', 'escada', 'ulric de varens', 'david yurman', 'swarovski', 'orchid perfumes', 'myrurgia', 'jean patou', 'emilio pucci', 'bvlgari', 'courvoisier', 'bill blass', 'guerlain', 'donna karan dkny', 'marc jacobs', 'balenciaga cristobal', 'house of sillage', 'caldion', 'karl lagerfeld', 'simone cosac profumi', 'aramis', 'michael kors', 'roberto cavalli', 'burberry', 'bebe', 'atkinsons', 'custo barcelona', 'versace', 'fly falcone', 'tom ford', 'ferragamo salvatore', 'valentino', 'serge lutens', 'esteban', 'escentric molecules', 'amorino prive', 'kilian', 'bentley', 'christian lacroix', 'krizia', 'mexx', 'christina aguilera', 'gian marco venturi', 'ferre', 'chloe', 'carolina herrera', 'jo malone', 'umbro', 'louis feraud', 'jesus del pozo', 'cristiano ronaldo', 'thierry mugler', 'elie saab le parfum', 'yves saint laurent', 'elizabeth arden', 'jean paul gaultier', 'gloria vanderbilt', 'mandarina duck', 'estee lauder', 'giulietta capuleti', 'lady gaga', 'dolce & gabbana', 'remy latour', 'tacchini', 'boucheron', 'guy laroche', 'guess', 'blumarine', 'pani walewska', 'costume national', 'coach', 'clinique', 'diptyque', 'balmain', 'chevignon', 'comme des garcons', 'nina ricci', 'armani', 'moresque', 'calvin klein', 'christian audigier', 'al hamatt', 'britney spears', 'juliette has a gun', 'cerruti', 'acqua di parma', 'armand basi', 'moschino', 'tiziana terenzi', 'azzaro', 'courreges', 'van cleef & arpels', 'hollister', 'davidoff', 'dsquared2', 'jacques bogart', 'schwarzkopf', 'vera wang', 'amouage', 'alfred dunhill', 'judith leiber', 'bottega veneta', 'adidas', 'abercrombie & fitch', 'alaia', 'ermenegildo zegna', 'lm parfums', 'tommy hilfiger', 'mancera', 'jimmy choo', 'miu miu', 'hermes', 'paco rabanne', 'roberto verino', 'playboy', 'laura biagiotti', 'amouroud', 'creed', 'paloma picasso', 'john richmond', 'lancome', 'jose eisenberg', 'anna sui', 'baldinini', 'olfactive studio', 'alexandre j.', 'atelier cologne', "victoria's secret", 'hugo boss', 'rochas', 'renegades', 'kenzo', "penhaligon's", 'dupont s.t.', 'sisley', 'lalique', 'princesse marina de bourbon', 'shakira', 'canali', 'sean john', 'signature fragrances', 'xerjoff', 'iceberg', 'givenchy', 'cacharel', 'antonio banderas', 'shiseido', 'ajmal', 'stella mccartney', 'david beckham', 'ghost', 'carner barcelona', 'john varvatos', 'jean couturier', 'agent provocateur', 'jil sander', 'banana republic', 'jennifer lopez', 'trussardi', 'porsche design', 'ellen tracy', 'hummer', 'ralph lauren', 'angel schlesser', 'narciso rodriguez', 'lolita lempicka', 'chambor', 'zhirinovsky', 'viktor & rolf', 'byc moze', 'cafe-cafe', 'boadicea the victorious', 'montale', 'beyonce', 'memo', 'zadig & voltaire', 'juicy couture', 'loewe', 'clive christian', "d'orsay", 'byredo', 'katy perry', 'gucci', 'franck olivier', 'lee cooper', 'nasomatto', 'm. micallef', 'dear rose', 'chanel', 'shaik', 'stefano ricci', 'diesel', 'ted lapidus', 'aquolina', 'harajuku lovers', 'y.yamamoto', 'la perla', 'chopard', 'al haramain', 'v canto', 'zarkoperfume', 'tous', 'belletete', 'masaki matsushima', 'bruno banani', 'baldessarini', 'ex nihilo', 'issey miyake', 'korloff', 'frapin', 'francis kurkdjian', 'mont blanc', 'fendi', 'prada', 'alla pugacheva', 'eon productions', 'ferrari', 'emanuel ungaro', 'lanvin', 'ramon molvizar', 'sarah jessica parker', 'slava zaitsev', 'cartier', 'lacoste', 'salvador dali', 'the woods collection', 'mazzolari', 'dior', 'parfums de marly', 'bamotte', 'madonna']

# %%
len(result_list)
# Out:
# 234

# %%
v = {}
for count, el in enumerate(result_list):
    print(el)
    s = str(input()).lower()
    v[count] = s
# Out:
# geoffrey beene
# geoffrey beene
# jessica mcclintock
# Jessica McClintock
# john galliano
# John Galliano
# asgharali
# Asgharali
# escada
# Escada
# ulric de varens
# Ulric de Varens
# david yurman
# David Yurman
# swarovski
# Swarowski
# orchid perfumes
# -
# myrurgia
# Myrurgia
# jean patou
# Jean PAtou
# emilio pucci
# Emilio Pucci
# bvlgari
# Bvlgari
# courvoisier
# Courvoisier Cognac
# bill blass
# bill blass
# guerlain
# guerlain
# donna karan dkny
# donna karan
# marc jacobs
# marc jacobs
# balenciaga cristobal
# balenciaga
# house of sillage
# house of sillage
# caldion
# -
# karl lagerfeld
# karl lagerfeld
# simone cosac profumi
# simone cosac profumi
# aramis
# aramis
# michael kors
# michael kors
# roberto cavalli
# roberto cavalli
# burberry
# burberry
# bebe
# bebe
# atkinsons
# atkinsons
# custo barcelona
# custo barcelona
# versace
# versace
# fly falcone
# -
# tom ford
# tom ford
# ferragamo salvatore
# Salvatore Ferragamo
# valentino
# valentino
# serge lutens
# serge lutens
# esteban
# esteban.
# escentric molecules
# escentric molecules
# amorino prive
# -
# kilian
# by kilian
# bentley
# bentley
# christian lacroix
# christian lacroix
# krizia
# krizia
# mexx
# mexx
# christina aguilera
# christina aguilera
# gian marco venturi
# gianmarco venturi
# ferre
# Gianfranco Ferre
# chloe
# chloe
# carolina herrera
# carolina herrera
# jo malone
# jo malone london
# umbro
# umbro
# louis feraud
# louis feraud
# jesus del pozo
# jesus del pozo
# cristiano ronaldo
# cristiano ronaldo
# thierry mugler
# mugler
# elie saab le parfum
# elie saab
# yves saint laurent
# yves saint laurent
# elizabeth arden
# elizabeth arden
# jean paul gaultier
# jean paul gaultier
# gloria vanderbilt
# gloria vanderbilt
# mandarina duck
# mandarina duck
# estee lauder
# Estée Lauder
# giulietta capuleti
# giulietta capuleti
# lady gaga
# lady gaga
# dolce & gabbana
# Dolce&Gabbana
# remy latour
# remy latour
# tacchini
# Sergio Tacchini
# boucheron
# boucheron
# guy laroche
# guy laroche
# guess
# guess
# blumarine
# blumarine
# pani walewska
# Miraculum
# costume national
# costume national
# coach
# coach
# clinique
# clinique
# diptyque
# diptyque
# balmain
# Pierre Balmain
# chevignon
# chevignon
# comme des garcons
# comme des garcons
# nina ricci
# nina ricci
# armani
# Giorgio Armani
# moresque
# moresque
# calvin klein
# calvin klein
# christian audigier
# christian audigier
# al hamatt
# -
# britney spears
# britney spears
# juliette has a gun
# juliette has a gun
# cerruti
# cerruti
# acqua di parma
# acqua di parma
# armand basi
# armand basi
# moschino
# moschino
# tiziana terenzi
# tiziana terenzi
# azzaro
# azzaro
# courreges
# courreges
# van cleef & arpels
# van cleef & arpels
# hollister
# hollister
# davidoff
# davidoff
# dsquared2
# -
# jacques bogart
# jacques bogart
# schwarzkopf
# -
# vera wang
# vera wang
# amouage
# amouage
# alfred dunhill
# alfred dunhill
# judith leiber
# judith leiber
# bottega veneta
# bottega veneta
# adidas
# adidas
# abercrombie & fitch
# abercrombie & fitch
# alaia
# alaia paris
# ermenegildo zegna
# ermenegildo zegna
# lm parfums
# lm parfums
# tommy hilfiger
# tommy hilfiger
# mancera
# mancera
# jimmy choo
# jimmy choo
# miu miu
# miu miu
# hermes
# Hermès
# paco rabanne
# paco rabanne
# roberto verino
# roberto verino
# playboy
# playboy
# laura biagiotti
# laura biagiotti
# amouroud
# amouroud
# creed
# creed
# paloma picasso
# paloma picasso
# john richmond
# john richmond
# lancome
# lancome
# jose eisenberg
# -
# anna sui
# anna sui
# baldinini
# baldinini
# olfactive studio
# olfactive studio
# alexandre j.
# alexandre j.
# atelier cologne
# atelier cologne
# victoria's secret
# Victoria`s Secret
# hugo boss
# hugo boss
# rochas
# rochas
# renegades
# renegades
# kenzo
# kenzo
# penhaligon's
# Penhaligon`s
# dupont s.t.
# S.T. Dupont
# sisley
# sisley
# lalique
# lalique
# princesse marina de bourbon
# princesse marina de bourbon
# shakira
# shakira
# canali
# canali
# sean john
# sean john
# signature fragrances
# signature fragrances
# xerjoff
# xerjoff
# iceberg
# iceberg
# givenchy
# givenchy
# cacharel
# cacharel
# antonio banderas
# antonio banderas
# shiseido
# shiseido
# ajmal
# ajmal
# stella mccartney
# Stella McCartney
# david beckham
# david beckham
# ghost
# ghost
# carner barcelona
# carner barcelona
# john varvatos
# john varvatos
# jean couturier
# jean couturier
# agent provocateur
# agent provocateur
# jil sander
# jil sander
# banana republic
# banana republic
# jennifer lopez
# jennifer lopez
# trussardi
# trussardi
# porsche design
# porsche design
# ellen tracy
# ellen tracy
# hummer
# hummer
# ralph lauren
# ralph lauren
# angel schlesser
# angel schlesser
# narciso rodriguez
# narciso rodriguez
# lolita lempicka
# lolita lempicka
# chambor
# -
# zhirinovsky
# zhirinovsky
# viktor & rolf
# Viktor&Rolf
# byc moze
# Miraculum
# cafe-cafe
# Cafe Parfums
# boadicea the victorious
# boadicea the victorious
# montale
# montale
# beyonce
# beyonce
# memo
# memo paris
# zadig & voltaire
# zadig & voltaire
# juicy couture
# juicy couture
# loewe
# loewe
# clive christian
# clive christian
# d'orsay
# D`Orsay
# byredo
# byredo
# katy perry
# katy perry
# gucci
# gucci
# franck olivier
# franck olivier
# lee cooper
# Lee Cooper Originals
# nasomatto
# nasomatto
# m. micallef
# m. micallef
# dear rose
# dear rose
# chanel
# chanel
# shaik
# shaik
# stefano ricci
# stefano ricci
# diesel
# diesel
# ted lapidus
# ted lapidus
# aquolina
# aquolina
# harajuku lovers
# harajuku lovers
# y.yamamoto
# -
# la perla
# la perla
# chopard
# chopard
# al haramain
# Al Haramain Perfumes
# v canto
# v canto
# zarkoperfume
# zarkoperfume
# tous
# tous
# belletete
# -
# masaki matsushima
# masaki matsushima
# bruno banani
# bruno banani
# baldessarini
# baldessarini
# ex nihilo
# ex nihilo
# issey miyake
# issey miyake
# korloff
# korloff paris
# frapin
# frapin
# francis kurkdjian
# Maison Francis Kurkdjian
# mont blanc
# montblanc
# fendi
# fendi
# prada
# prada
# alla pugacheva
# alla pugacheva
# eon productions
# eon productions
# ferrari
# ferrari
# emanuel ungaro
# emanuel ungaro
# lanvin
# lanvin
# ramon molvizar
# ramon molvizar
# sarah jessica parker
# sarah jessica parker
# slava zaitsev
# slava zaitsev
# cartier
# cartier
# lacoste
# Lacoste Fragrances
# salvador dali
# salvador dali
# the woods collection
# the woods collection
# mazzolari
# mazzolari
# dior
# Christian Dior
# parfums de marly
# parfums de marly
# bamotte
# bamotte
# madonna
# madonna

# %%
v
# Out:
# {0: 'geoffrey beene',
#  1: 'jessica mcclintock',
#  2: 'john galliano',
#  3: 'asgharali',
#  4: 'escada',
#  5: 'ulric de varens',
#  6: 'david yurman',
#  7: 'swarowski',
#  8: '-',
#  9: 'myrurgia',
#  10: 'jean patou',
#  11: 'emilio pucci',
#  12: 'bvlgari',
#  13: 'courvoisier cognac',
#  14: 'bill blass',
#  15: 'guerlain',
#  16: 'donna karan',
#  17: 'marc jacobs',
#  18: 'balenciaga',
#  19: 'house of sillage',
#  20: '-',
#  21: 'karl lagerfeld',
#  22: 'simone cosac profumi',
#  23: 'aramis',
#  24: 'michael kors',
#  25: 'roberto cavalli',
#  26: 'burberry',
#  27: 'bebe',
#  28: 'atkinsons',
#  29: 'custo barcelona',
#  30: 'versace',
#  31: '-',
#  32: 'tom ford',
#  33: 'salvatore ferragamo',
#  34: 'valentino',
#  35: 'serge lutens',
#  36: 'esteban.',
#  37: 'escentric molecules',
#  38: '-',
#  39: 'by kilian',
#  40: 'bentley',
#  41: 'christian lacroix',
#  42: 'krizia',
#  43: 'mexx',
#  44: 'christina aguilera',
#  45: 'gianmarco venturi',
#  46: 'gianfranco ferre',
#  47: 'chloe',
#  48: 'carolina herrera',
#  49: 'jo malone london',
#  50: 'umbro',
#  51: 'louis feraud',
#  52: 'jesus del pozo',
#  53: 'cristiano ronaldo',
#  54: 'mugler',
#  55: 'elie saab',
#  56: 'yves saint laurent',
#  57: 'elizabeth arden',
#  58: 'jean paul gaultier',
#  59: 'gloria vanderbilt',
#  60: 'mandarina duck',
#  61: 'estée lauder',
#  62: 'giulietta capuleti',
#  63: 'lady gaga',
#  64: 'dolce&gabbana',
#  65: 'remy latour',
#  66: 'sergio tacchini',
#  67: 'boucheron',
#  68: 'guy laroche',
#  69: 'guess',
#  70: 'blumarine',
#  71: 'miraculum',
#  72: 'costume national',
#  73: 'coach',
#  74: 'clinique',
#  75: 'diptyque',
#  76: 'pierre balmain',
#  77: 'chevignon',
#  78: 'comme des garcons',
#  79: 'nina ricci',
#  80: 'giorgio armani',
#  81: 'moresque',
#  82: 'calvin klein',
#  83: 'christian audigier',
#  84: '-',
#  85: 'britney spears',
#  86: 'juliette has a gun',
#  87: 'cerruti',
#  88: 'acqua di parma',
#  89: 'armand basi',
#  90: 'moschino',
#  91: 'tiziana terenzi',
#  92: 'azzaro',
#  93: 'courreges',
#  94: 'van cleef & arpels',
#  95: 'hollister',
#  96: 'davidoff',
#  97: '-',
#  98: 'jacques bogart',
#  99: '-',
#  100: 'vera wang',
#  101: 'amouage',
#  102: 'alfred dunhill',
#  103: 'judith leiber',
#  104: 'bottega veneta',
#  105: 'adidas',
#  106: 'abercrombie & fitch',
#  107: 'alaia paris',
#  108: 'ermenegildo zegna',
#  109: 'lm parfums',
#  110: 'tommy hilfiger',
#  111: 'mancera',
#  112: 'jimmy choo',
#  113: 'miu miu',
#  114: 'hermès',
#  115: 'paco rabanne',
#  116: 'roberto verino',
#  117: 'playboy',
#  118: 'laura biagiotti',
#  119: 'amouroud',
#  120: 'creed',
#  121: 'paloma picasso',
#  122: 'john richmond',
#  123: 'lancome',
#  124: '-',
#  125: 'anna sui',
#  126: 'baldinini',
#  127: 'olfactive studio',
#  128: 'alexandre j.',
#  129: 'atelier cologne',
#  130: 'victoria`s secret',
#  131: 'hugo boss',
#  132: 'rochas',
#  133: 'renegades',
#  134: 'kenzo',
#  135: 'penhaligon`s',
#  136: 's.t. dupont',
#  137: 'sisley',
#  138: 'lalique',
#  139: 'princesse marina de bourbon',
#  140: 'shakira',
#  141: 'canali',
#  142: 'sean john',
#  143: 'signature fragrances',
#  144: 'xerjoff',
#  145: 'iceberg',
#  146: 'givenchy',
#  147: 'cacharel',
#  148: 'antonio banderas',
#  149: 'shiseido',
#  150: 'ajmal',
#  151: 'stella mccartney',
#  152: 'david beckham',
#  153: 'ghost',
#  154: 'carner barcelona',
#  155: 'john varvatos',
#  156: 'jean couturier',
#  157: 'agent provocateur',
#  158: 'jil sander',
#  159: 'banana republic',
#  160: 'jennifer lopez',
#  161: 'trussardi',
#  162: 'porsche design',
#  163: 'ellen tracy',
#  164: 'hummer',
#  165: 'ralph lauren',
#  166: 'angel schlesser',
#  167: 'narciso rodriguez',
#  168: 'lolita lempicka',
#  169: '-',
#  170: 'zhirinovsky',
#  171: 'viktor&rolf',
#  172: 'miraculum',
#  173: 'cafe parfums',
#  174: 'boadicea the victorious',
#  175: 'montale',
#  176: 'beyonce',
#  177: 'memo paris',
#  178: 'zadig & voltaire',
#  179: 'juicy couture',
#  180: 'loewe',
#  181: 'clive christian',
#  182: 'd`orsay',
#  183: 'byredo',
#  184: 'katy perry',
#  185: 'gucci',
#  186: 'franck olivier',
#  187: 'lee cooper originals',
#  188: 'nasomatto',
#  189: 'm. micallef',
#  190: 'dear rose',
#  191: 'chanel',
#  192: 'shaik',
#  193: 'stefano ricci',
#  194: 'diesel',
#  195: 'ted lapidus',
#  196: 'aquolina',
#  197: 'harajuku lovers',
#  198: '-',
#  199: 'la perla',
#  200: 'chopard',
#  201: 'al haramain perfumes',
#  202: 'v canto',
#  203: 'zarkoperfume',
#  204: 'tous',
#  205: '-',
#  206: 'masaki matsushima',
#  207: 'bruno banani',
#  208: 'baldessarini',
#  209: 'ex nihilo',
#  210: 'issey miyake',
#  211: 'korloff paris',
#  212: 'frapin',
#  213: 'maison francis kurkdjian',
#  214: 'montblanc',
#  215: 'fendi',
#  216: 'prada',
#  217: 'alla pugacheva',
#  218: 'eon productions',
#  219: 'ferrari',
#  220: 'emanuel ungaro',
#  221: 'lanvin',
#  222: 'ramon molvizar',
#  223: 'sarah jessica parker',
#  224: 'slava zaitsev',
#  225: 'cartier',
#  226: 'lacoste fragrances',
#  227: 'salvador dali',
#  228: 'the woods collection',
#  229: 'mazzolari',
#  230: 'christian dior',
#  231: 'parfums de marly',
#  232: 'bamotte',
#  233: 'madonna'}

# %%
v[36] = 'esteban'

# %%
v
# Out:
# {0: 'geoffrey beene',
#  1: 'jessica mcclintock',
#  2: 'john galliano',
#  3: 'asgharali',
#  4: 'escada',
#  5: 'ulric de varens',
#  6: 'david yurman',
#  7: 'swarowski',
#  8: '-',
#  9: 'myrurgia',
#  10: 'jean patou',
#  11: 'emilio pucci',
#  12: 'bvlgari',
#  13: 'courvoisier cognac',
#  14: 'bill blass',
#  15: 'guerlain',
#  16: 'donna karan',
#  17: 'marc jacobs',
#  18: 'balenciaga',
#  19: 'house of sillage',
#  20: '-',
#  21: 'karl lagerfeld',
#  22: 'simone cosac profumi',
#  23: 'aramis',
#  24: 'michael kors',
#  25: 'roberto cavalli',
#  26: 'burberry',
#  27: 'bebe',
#  28: 'atkinsons',
#  29: 'custo barcelona',
#  30: 'versace',
#  31: '-',
#  32: 'tom ford',
#  33: 'salvatore ferragamo',
#  34: 'valentino',
#  35: 'serge lutens',
#  36: 'esteban',
#  37: 'escentric molecules',
#  38: '-',
#  39: 'by kilian',
#  40: 'bentley',
#  41: 'christian lacroix',
#  42: 'krizia',
#  43: 'mexx',
#  44: 'christina aguilera',
#  45: 'gianmarco venturi',
#  46: 'gianfranco ferre',
#  47: 'chloe',
#  48: 'carolina herrera',
#  49: 'jo malone london',
#  50: 'umbro',
#  51: 'louis feraud',
#  52: 'jesus del pozo',
#  53: 'cristiano ronaldo',
#  54: 'mugler',
#  55: 'elie saab',
#  56: 'yves saint laurent',
#  57: 'elizabeth arden',
#  58: 'jean paul gaultier',
#  59: 'gloria vanderbilt',
#  60: 'mandarina duck',
#  61: 'estée lauder',
#  62: 'giulietta capuleti',
#  63: 'lady gaga',
#  64: 'dolce&gabbana',
#  65: 'remy latour',
#  66: 'sergio tacchini',
#  67: 'boucheron',
#  68: 'guy laroche',
#  69: 'guess',
#  70: 'blumarine',
#  71: 'miraculum',
#  72: 'costume national',
#  73: 'coach',
#  74: 'clinique',
#  75: 'diptyque',
#  76: 'pierre balmain',
#  77: 'chevignon',
#  78: 'comme des garcons',
#  79: 'nina ricci',
#  80: 'giorgio armani',
#  81: 'moresque',
#  82: 'calvin klein',
#  83: 'christian audigier',
#  84: '-',
#  85: 'britney spears',
#  86: 'juliette has a gun',
#  87: 'cerruti',
#  88: 'acqua di parma',
#  89: 'armand basi',
#  90: 'moschino',
#  91: 'tiziana terenzi',
#  92: 'azzaro',
#  93: 'courreges',
#  94: 'van cleef & arpels',
#  95: 'hollister',
#  96: 'davidoff',
#  97: '-',
#  98: 'jacques bogart',
#  99: '-',
#  100: 'vera wang',
#  101: 'amouage',
#  102: 'alfred dunhill',
#  103: 'judith leiber',
#  104: 'bottega veneta',
#  105: 'adidas',
#  106: 'abercrombie & fitch',
#  107: 'alaia paris',
#  108: 'ermenegildo zegna',
#  109: 'lm parfums',
#  110: 'tommy hilfiger',
#  111: 'mancera',
#  112: 'jimmy choo',
#  113: 'miu miu',
#  114: 'hermès',
#  115: 'paco rabanne',
#  116: 'roberto verino',
#  117: 'playboy',
#  118: 'laura biagiotti',
#  119: 'amouroud',
#  120: 'creed',
#  121: 'paloma picasso',
#  122: 'john richmond',
#  123: 'lancome',
#  124: '-',
#  125: 'anna sui',
#  126: 'baldinini',
#  127: 'olfactive studio',
#  128: 'alexandre j.',
#  129: 'atelier cologne',
#  130: 'victoria`s secret',
#  131: 'hugo boss',
#  132: 'rochas',
#  133: 'renegades',
#  134: 'kenzo',
#  135: 'penhaligon`s',
#  136: 's.t. dupont',
#  137: 'sisley',
#  138: 'lalique',
#  139: 'princesse marina de bourbon',
#  140: 'shakira',
#  141: 'canali',
#  142: 'sean john',
#  143: 'signature fragrances',
#  144: 'xerjoff',
#  145: 'iceberg',
#  146: 'givenchy',
#  147: 'cacharel',
#  148: 'antonio banderas',
#  149: 'shiseido',
#  150: 'ajmal',
#  151: 'stella mccartney',
#  152: 'david beckham',
#  153: 'ghost',
#  154: 'carner barcelona',
#  155: 'john varvatos',
#  156: 'jean couturier',
#  157: 'agent provocateur',
#  158: 'jil sander',
#  159: 'banana republic',
#  160: 'jennifer lopez',
#  161: 'trussardi',
#  162: 'porsche design',
#  163: 'ellen tracy',
#  164: 'hummer',
#  165: 'ralph lauren',
#  166: 'angel schlesser',
#  167: 'narciso rodriguez',
#  168: 'lolita lempicka',
#  169: '-',
#  170: 'zhirinovsky',
#  171: 'viktor&rolf',
#  172: 'miraculum',
#  173: 'cafe parfums',
#  174: 'boadicea the victorious',
#  175: 'montale',
#  176: 'beyonce',
#  177: 'memo paris',
#  178: 'zadig & voltaire',
#  179: 'juicy couture',
#  180: 'loewe',
#  181: 'clive christian',
#  182: 'd`orsay',
#  183: 'byredo',
#  184: 'katy perry',
#  185: 'gucci',
#  186: 'franck olivier',
#  187: 'lee cooper originals',
#  188: 'nasomatto',
#  189: 'm. micallef',
#  190: 'dear rose',
#  191: 'chanel',
#  192: 'shaik',
#  193: 'stefano ricci',
#  194: 'diesel',
#  195: 'ted lapidus',
#  196: 'aquolina',
#  197: 'harajuku lovers',
#  198: '-',
#  199: 'la perla',
#  200: 'chopard',
#  201: 'al haramain perfumes',
#  202: 'v canto',
#  203: 'zarkoperfume',
#  204: 'tous',
#  205: '-',
#  206: 'masaki matsushima',
#  207: 'bruno banani',
#  208: 'baldessarini',
#  209: 'ex nihilo',
#  210: 'issey miyake',
#  211: 'korloff paris',
#  212: 'frapin',
#  213: 'maison francis kurkdjian',
#  214: 'montblanc',
#  215: 'fendi',
#  216: 'prada',
#  217: 'alla pugacheva',
#  218: 'eon productions',
#  219: 'ferrari',
#  220: 'emanuel ungaro',
#  221: 'lanvin',
#  222: 'ramon molvizar',
#  223: 'sarah jessica parker',
#  224: 'slava zaitsev',
#  225: 'cartier',
#  226: 'lacoste fragrances',
#  227: 'salvador dali',
#  228: 'the woods collection',
#  229: 'mazzolari',
#  230: 'christian dior',
#  231: 'parfums de marly',
#  232: 'bamotte',
#  233: 'madonna'}

# %%
v1 = v.copy() # несмэтченные

# %%
matched = list(set(df['lowVendor'].unique().tolist()) and set(df['lowBrand'].unique().tolist()))

# %%
matched
# Out:
# [nan,
#  ' peter jacobs parfum  ',
#  ' jean d`albret  ',
#  ' jivago  ',
#  ' juliana paes  ',
#  ' mayssa  ',
#  ' salvatore ferragamo  ',
#  ' jill stuart  ',
#  ' beyonce  ',
#  ' héloïse de v.  ',
#  ' jean reno  ',
#  ' la sucrerie de la montagne  ',
#  ' tom rebl  ',
#  ' lexington  ',
#  ' centurion parfums  ',
#  ' grassroots  ',
#  ' be. colonias  ',
#  ' des filles a la vanille  ',
#  ' frank govers  ',
#  ' bath house  ',
#  ' martine marie laurent  ',
#  ' mimmina  ',
#  ' musc et madame  ',
#  ' theo parfums  ',
#  ' maori collection  ',
#  ' morgane le fay  ',
#  ' angel schlesser  ',
#  ' emporio body store  ',
#  ' chiara boni  ',
#  ' lulah  ',
#  ' titanium man  ',
#  ' olivier durbano  ',
#  ' jane booke  ',
#  ' cvs essence of beauty  ',
#  ' olivina men  ',
#  ' stella mccartney  ',
#  ' anastacia  ',
#  ' dynasty  ',
#  ' stilllife  ',
#  ' electimuss  ',
#  ' massoïa secrets  ',
#  ' poiray  ',
#  ' arabiyat  ',
#  ' cristina ferreira  ',
#  ' luce fragrance  ',
#  ' arielle shoshana  ',
#  ' arrogance  ',
#  ' ricki hall and captain fawcett  ',
#  ' bobbi brown  ',
#  ' christian lacroix  ',
#  ' gainsboro  ',
#  ' coastal fragrance  ',
#  ' corine de farme  ',
#  ' olibere parfums  ',
#  ' jessica simpson  ',
#  ' note33  ',
#  ' les nereides  ',
#  ' schlossparfumerie  ',
#  ' vitrue paris  ',
#  ' yas perfumes  ',
#  ' tonelli  ',
#  ' prince  ',
#  ' fragrifert parfumeur  ',
#  ' oxbow  ',
#  ' widian  ',
#  ' the sum  ',
#  ' zirh  ',
#  ' sarah jessica parker  ',
#  ' bex london  ',
#  ' the fragrance engineers  ',
#  ' suleko  ',
#  ' bejar  ',
#  ' mastiha shop  ',
#  ' nanadebary  ',
#  ' one of those  ',
#  ' ars mirabile  ',
#  ' l`erbolario  ',
#  ' caron  ',
#  ' arty fragrance by elisabeth de feydeau  ',
#  ' s.a.c.k.y  ',
#  ' alexander mcqueen  ',
#  ' possets perfume  ',
#  ' yanbal  ',
#  ' mirra  ',
#  ' the cotswold perfumery  ',
#  ' faberlic  ',
#  ' torre of tuscany  ',
#  ' reiss  ',
#  ' vicky tiel  ',
#  ' avon  ',
#  ' derbe  ',
#  ' herve leger  ',
#  ' sg79 sthlm  ',
#  ' chantecaille  ',
#  ' l`essence des notes  ',
#  ' valor  ',
#  ' vinci  ',
#  ' pineider  ',
#  ' cuarzo the circle  ',
#  ' la ric  ',
#  ' george gina & lucy  ',
#  ' gwendolyn-mary  ',
#  ' jaguar  ',
#  ' susan mccray  ',
#  ' brandy parfums  ',
#  ' parfums elite  ',
#  ' merveille de france  ',
#  ' belsans  ',
#  ' jacques battini  ',
#  ' myropol  ',
#  ' seven skies  ',
#  ' shelley kyle  ',
#  ' alfred sung  ',
#  ' diana ross  ',
#  ' stacked style  ',
#  ' erno laszlo  ',
#  ' mizensir  ',
#  ' the spirit of dubai  ',
#  ' parfums marco serussi  ',
#  ' coppeneur  ',
#  ' instyle  ',
#  ' fiorucci  ',
#  ' giulietta capuleti  ',
#  ' chaugan  ',
#  ' jardin de france  ',
#  ' miss anastasia  ',
#  ' david bustamante  ',
#  ' la collina toscana  ',
#  ' suhad perfumes  ',
#  ' angela flanders  ',
#  ' sephora  ',
#  ' porsche design  ',
#  ' nadia z  ',
#  ' note fragrances  ',
#  ' emeshel  ',
#  ' orla kiely  ',
#  ' star wars perfumes  ',
#  ' pout  ',
#  ' lee cooper originals  ',
#  ' chabrawichi  ',
#  ' von eusersdorff  ',
#  ' coronation ambergris  ',
#  ' albert nipon  ',
#  ' fenjal  ',
#  ' flumen profumi  ',
#  ' daddy yankee  ',
#  ' godet  ',
#  ' sonoma scent studio  ',
#  ' prescriptives  ',
#  ' memphis  ',
#  ' jls  ',
#  ' camp beverly hills  ',
#  ' createurs cosmetiques  ',
#  ' rituals  ',
#  ' tracy reese  ',
#  ' royal apothic  ',
#  ' opsobjects  ',
#  ' dana buchman  ',
#  ' paglieri  ',
#  ' mark birley  ',
#  ' jean luc amsler  ',
#  ' gerani  ',
#  ' leh perfumes  ',
#  ' esperienze olfattive  ',
#  ' nabeel  ',
#  ' jovan  ',
#  ' roveri & aura  ',
#  ' april aromatics  ',
#  ' montale  ',
#  ' orlov paris  ',
#  ' cyzone  ',
#  ' nazareno gabrielli  ',
#  ' natural scents  ',
#  ' austin young  ',
#  ' sauf  ',
#  ' dr. vranjes firenze  ',
#  ' alta moda  ',
#  ' extrait d`atelier  ',
#  ' so...?  ',
#  ' sorelle fontana  ',
#  ' veejaga  ',
#  ' acorelle  ',
#  ' aquolina  ',
#  ' weleda  ',
#  ' modern lady 摩登红人  ',
#  ' agatha ruiz de la prada  ',
#  ' id parfums  ',
#  ' ein gedi  ',
#  ' jacques fath  ',
#  ' kajal  ',
#  ' rose en bos  ',
#  ' être au parfum  ',
#  ' s.t. dupont  ',
#  ' kush perfume  ',
#  ' prudence paris  ',
#  ' costes  ',
#  ' the lab room  ',
#  ' unitop  ',
#  ' women secret  ',
#  ' sunnamusk  ',
#  ' mariella martinato  ',
#  ' blancheide  ',
#  ' urban rituelle  ',
#  ' matthew decker  ',
#  ' stefano canturi  ',
#  ' bliss  ',
#  ' anne möller  ',
#  ' richard lüscher britos  ',
#  ' bonny doon farm  ',
#  ' illume  ',
#  ' lamis atef  ',
#  ' intimissimi  ',
#  ' macal palma  ',
#  ' christian tortu  ',
#  ' herban cowboy  ',
#  ' memento italian olfactive landscapes  ',
#  ' azzaro  ',
#  ' fragrances of wine  ',
#  ' prince henri d`orleans  ',
#  ' samantha faiers  ',
#  ' lotus  ',
#  ' anna dello russo  ',
#  ' erreuno  ',
#  ' keiko mecheri  ',
#  ' muhammad ali  ',
#  ' feminista  ',
#  ' les parfums de rosine  ',
#  ' eternel gentleman  ',
#  ' alan cumming  ',
#  ' laboratorio olfattivo  ',
#  ' coral  ',
#  ' jaclyn smith  ',
#  ' bi-es  ',
#  ' monika klink  ',
#  ' brioni  ',
#  ' six scents  ',
#  ' imperio lusso  ',
#  ' reem acra  ',
#  ' aeon  ',
#  ' the crown perfumery co.  ',
#  ' pamela anderson  ',
#  ' prouvenco  ',
#  ' antica farmacista  ',
#  ' blauer  ',
#  ' erik kormann  ',
#  ' alexandria fragrances  ',
#  ' m.int  ',
#  ' sammi sweetheart  ',
#  ' pirette  ',
#  ' taylor of old bond street  ',
#  ' v`tae  ',
#  ' serge lutens  ',
#  ' anima vinci  ',
#  ' perfumer`s workshop  ',
#  ' dear diary  ',
#  ' tarte cosmetics  ',
#  ' dr. grandel  ',
#  ' hi wildflower botanica  ',
#  ' bobby jones  ',
#  ' reed krakoff  ',
#  ' mustang  ',
#  ' patti labelle  ',
#  ' izod  ',
#  ' etienne barre  ',
#  ' mark wright  ',
#  ' she who dares  ',
#  ' mariah carey  ',
#  ' fruits & passion  ',
#  ' aroma karelia  ',
#  ' acqua di portokali  ',
#  ' stella & dustin  ',
#  ' eric buterbaugh florals  ',
#  ' marella ferrera  ',
#  ' shaneela rowah al-qamar  ',
#  ' esscentual alchemy  ',
#  ' issey miyake  ',
#  ' tiens  ',
#  ' emporium  ',
#  ' santa fe botanical natural fragrance collection  ',
#  ' anthousa  ',
#  ' imaginary authors  ',
#  ' tambela natural perfumes  ',
#  ' daniel josier  ',
#  ' avery  ',
#  ' aveda  ',
#  ' i caratteri  ',
#  ' paul & joe  ',
#  ' badgley mischka  ',
#  ' grossmith  ',
#  ' marquay  ',
#  ' thompson ferrier  ',
#  ' manchester  ',
#  ' project d by dannii and tabitha  ',
#  ' thomas kosmala  ',
#  ' rimmel  ',
#  ' jads international  ',
#  ' coqui coqui  ',
#  ' jenni farley  ',
#  ' accessorize  ',
#  ' helan  ',
#  ' pantheon roma  ',
#  ' samourai  ',
#  ' alessandro  ',
#  ' rodier  ',
#  ' sahlini parfums  ',
#  ' the vagabond prince  ',
#  ' rich hippie  ',
#  ' charleston girl  ',
#  ' les cakes de bertrand  ',
#  ' gandini 1896  ',
#  ' nuxe  ',
#  ' parfums berdoues  ',
#  ' love passport  ',
#  ' lr  ',
#  ' pecksniff`s  ',
#  ' perlier  ',
#  ' unique  ',
#  ' pierre guillaume  ',
#  ' myrurgia  ',
#  ' diadema exclusif  ',
#  ' essence of chi  ',
#  ' madonna nudes 1979  ',
#  ' eisenberg  ',
#  ' neom organics  ',
#  ' l`atelier boheme  ',
#  ' baldi  ',
#  ' rubini  ',
#  ' precious liquid  ',
#  ' jennica  ',
#  ' kitson  ',
#  ' ne`emah for fragrance & oudh  ',
#  ' hierbas de mallorca  ',
#  ' d`orsay  ',
#  ' swarovski  ',
#  ' mexx  ',
#  ' welton london  ',
#  ' jouany perfumes  ',
#  ' zeromolecole  ',
#  ' ajne  ',
#  ' decennial  ',
#  ' clean  ',
#  ' goodtruebeautiful  ',
#  ' panah london  ',
#  ' the royal perfume  ',
#  ' royal hawaiian  ',
#  ' acqua novara  ',
#  ' parfums valjean  ',
#  ' missala  ',
#  ' philippe venet  ',
#  ' j. lesquendieu  ',
#  ' nshq  ',
#  ' canoe  ',
#  ' gai mattiolo  ',
#  ' riva  ',
#  ' love&wish 爱唯施  ',
#  ' mury paris  ',
#  ' palmers  ',
#  ' sana jardin  ',
#  ' brooklyn soap company  ',
#  ' hard candy  ',
#  ' remy latour  ',
#  ' vartan perfumes  ',
#  ' nemat international  ',
#  ' christine darvin  ',
#  ' billy jealousy  ',
#  ' bershka  ',
#  ' hanae mori  ',
#  ' urban retreat  ',
#  ' rance 1795  ',
#  ' liu jo  ',
#  ' julio iglesias  ',
#  ' state of mind  ',
#  ' james heeley  ',
#  ' borghese  ',
#  ' de rauch  ',
#  ' pascal morabito  ',
#  ' dom prirody  ',
#  ' sergey gubanov  ',
#  ' mad et len  ',
#  ' sergio nero  ',
#  ' kanebo  ',
#  ' nocibé  ',
#  ' the party  ',
#  ' melissa flagg perfume  ',
#  ' elizabeth arden  ',
#  ' tabacora parfums  ',
#  ' irisch moos  ',
#  ' michelle michini  ',
#  ' lostmarch  ',
#  ' borbonese  ',
#  ' preeminence  ',
#  ' principessa beauty  ',
#  ' monsillage  ',
#  ' christian audigier  ',
#  ' antiga barbearia de bairro  ',
#  ' lily lambert  ',
#  ' limonero p.  ',
#  ' s4p  ',
#  ' dirk bikkembergs  ',
#  ' sergio soldano  ',
#  ' excelsis  ',
#  ' jordana parfums  ',
#  ' hadarah perfumes  ',
#  ' kimora lee simmons  ',
#  ' marc o`polo  ',
#  ' lomani  ',
#  ' shu uemura  ',
#  ' elisire  ',
#  ' chaz dean  ',
#  ' farmacia ss. annunziata  ',
#  ' drew barrymore  ',
#  ' rundholz  ',
#  ' mac  ',
#  ' wienerblut  ',
#  ' asprey london  ',
#  ' sooud  ',
#  ' wax poetic  ',
#  ' antica barbieria colla  ',
#  ' c&a  ',
#  ' lena hoschek  ',
#  ' jean-pierre sand  ',
#  ' maison gabriella chieffo  ',
#  ' souleiado  ',
#  ' m8 moods  ',
#  ' shawn mendes  ',
#  ' sue devitt  ',
#  ' anicka yi & maggie peng  ',
#  ' dzintars  ',
#  ' laura biagiotti  ',
#  ' lothantique  ',
#  ' a wing & a prayer perfumes  ',
#  ' wellments  ',
#  ' agustin davila  ',
#  ' s-perfume  ',
#  ' zoella beauty  ',
#  ' gap  ',
#  ' katy perry  ',
#  ' red flower organic perfume  ',
#  ' pininfarina  ',
#  ' ghandour  ',
#  ' odur  ',
#  ' agarscents bazaar  ',
#  ' vivasan  ',
#  ' ormonde jayne  ',
#  ' teone reinthal natural perfume  ',
#  ' le blanc  ',
#  ' art deco perfumes  ',
#  ' valentin yudashkin  ',
#  ' belinda brown  ',
#  ' dossage  ',
#  ' knize  ',
#  ' michael hill  ',
#  ' beaute marketing inc  ',
#  ' l’essence de mastenbroek  ',
#  ' versace  ',
#  ' ted lapidus  ',
#  ' vera bradley  ',
#  ' gres  ',
#  ' good chemistry  ',
#  ' abercrombie & fitch  ',
#  ' baug sons  ',
#  ' fabi  ',
#  ' alye parusa  ',
#  ' kosiuko  ',
#  ' jean desprez  ',
#  ' min new york  ',
#  ' island bath and body  ',
#  ' odin  ',
#  ' sézane  ',
#  ' blue q  ',
#  ' calgon  ',
#  ' jesse mccartney  ',
#  ' tina arena  ',
#  ' lotto  ',
#  ' beary  ',
#  ' john richmond  ',
#  ' libertin louison technique indiscrete  ',
#  ' heretic parfums  ',
#  ' nerd  ',
#  ' sisley  ',
#  ' maison anonyme  ',
#  ' agatha  ',
#  ' pereja  ',
#  ' kimberly wyatt  ',
#  ' marchesa  ',
#  ' julian rouas  ',
#  ' parfums 137  ',
#  ' exceptional parfums  ',
#  ' serge normant  ',
#  ' altern essence perfume  ',
#  ' parfums lalun  ',
#  ' one direction  ',
#  ' jean charles brosseau  ',
#  ' marc rosen  ',
#  ' jockey  ',
#  ' ghawali  ',
#  ' cliven  ',
#  ' loly in the sky  ',
#  ' dua fragrances  ',
#  ' omega  ',
#  ' morph  ',
#  ' parfums privilege  ',
#  ' david beckham  ',
#  ' marialux  ',
#  ' thefaceshop  ',
#  ' miu miu  ',
#  ' the grand budapest hotel  ',
#  ' jardin d`amour  ',
#  ' topmodel  ',
#  ' ferrari  ',
#  ' nicole farhi  ',
#  ' xoxo  ',
#  ' tammie garr  ',
#  ' grasse au parfum  ',
#  ' air-val international  ',
#  ' agnes b  ',
#  ' john player special  ',
#  ' osmogenes perfumes  ',
#  ' diptyque  ',
#  ' royal crown  ',
#  ' the bluebeards revenge  ',
#  ' soma  ',
#  ' usher  ',
#  ' cellcosmet  ',
#  ' phebo  ',
#  ' rue21  ',
#  ' palquis  ',
#  ' vapro international  ',
#  ' essenzialmente laura  ',
#  ' naso di raza  ',
#  ' arte profumi  ',
#  ' krigler  ',
#  ' montazami  ',
#  ' teresa helbig  ',
#  ' frankie morello  ',
#  ' monsoon  ',
#  ' bugatti  ',
#  ' infusion organique  ',
#  ' harajuku lovers  ',
#  ' magdala  ',
#  ' page parfums  ',
#  ' le prince jardinier  ',
#  ' romero britto  ',
#  ' n-cigale  ',
#  ' lush  ',
#  ' david haris  ',
#  ' harvey prince  ',
#  ' parisvally perfumes  ',
#  ' parfums matisse  ',
#  ' marina smith  ',
#  ' cristiano ronaldo  ',
#  ' jeanne arthes  ',
#  ' joaquin cortes  ',
#  ' torand  ',
#  ' lapp fragrances  ',
#  ' lise london  ',
#  ' social creatures  ',
#  ' rose of bulgaria  ',
#  ' ricardo ramos perfumes de autor  ',
#  ' e. coudray  ',
#  ' max azria  ',
#  ' mirato  ',
#  ' les indemodables  ',
#  ' playmobil  ',
#  ' kerry katona  ',
#  ' perfumes artesanales  ',
#  ' ralph lauren  ',
#  ' perfumes hedoné  ',
#  ' vigny  ',
#  ' axe  ',
#  ' hardeman  ',
#  ' farmasi  ',
#  ' make up store  ',
#  ' mauá  ',
#  ' parfums delrae  ',
#  ' vanessa somerset design  ',
#  ' yves rocher  ',
#  ' odori  ',
#  ' ricky sarkany  ',
#  ' isabel and ruben toledo  ',
#  ' garage  ',
#  ' hunca  ',
#  ' tromborg  ',
#  ' evaflor  ',
#  ' heidi klum  ',
#  ' room 1015  ',
#  ' visconti di modrone  ',
#  ' bissoumine  ',
#  ' mariella burani  ',
#  ' alesha dixon  ',
#  ' acquadì  ',
#  ' maison incens  ',
#  ' soap & paper factory  ',
#  ' c.o.bigelow  ',
#  ' manuel canovas  ',
#  ' asama perfumes  ',
#  ' marlou  ',
#  ' sarah kern  ',
#  ' al attar  ',
#  ' franck boclet  ',
#  ' diana vreeland  ',
#  ' scent salim  ',
#  ' isadora paris  ',
#  ' guru scent  ',
#  ' lulu beauty  ',
#  ' danijela martinovic  ',
#  ' natalie wood  ',
#  ' alford & hoff  ',
#  ' germaine de capuccini  ',
#  ' milton lloyd  ',
#  ' lavanila laboratories  ',
#  ' lidl  ',
#  ' gump`s  ',
#  ' halloween  ',
#  ' kiehl`s  ',
#  ' la facon  ',
#  ' proenza schouler  ',
#  ' slumberhouse  ',
#  ' hiram green  ',
#  ' la bouquetiere  ',
#  ' profile  ',
#  ' modigliani  ',
#  ' don algodon  ',
#  ' h&m  ',
#  ' marina yachting  ',
#  ' seth kornegay  ',
#  ' bath and body works  ',
#  ' paragon perfumes  ',
#  ' rihanna  ',
#  ' teatro fragranze uniche  ',
#  ' torrente  ',
#  ' prissana  ',
#  ' delle grazie  ',
#  ' ahjaar  ',
#  ' la senza  ',
#  ' iconix  ',
#  ' dame perfumery  ',
#  ' nanette lepore  ',
#  ' hildegard braukmann  ',
#  ' john galliano  ',
#  ' atelier oblique  ',
#  ' goti  ',
#  ' parfums du château de versailles  ',
#  ' ephemera by unsound  ',
#  ' yves saint laurent  ',
#  ' tommi sooni  ',
#  ' serious skin care  ',
#  ' chatillon lux parfums  ',
#  ' gabriela sabatini  ',
#  ' yohji yamamoto  ',
#  ' tufi duek  ',
#  ' frederic m  ',
#  ' you first pura rinascita  ',
#  ' bruno acampora  ',
#  ' lalaloopsy  ',
#  ' making of cannes  ',
#  ' mickey and friends  ',
#  ' momo design  ',
#  ' demeter fragrance  ',
#  ' henry cotton`s  ',
#  ' manny pacman pacquiao  ',
#  ' nest  ',
#  ' menelik fragrances  ',
#  ' molton brown  ',
#  ' nobile 1942  ',
#  ' paul donnant  ',
#  ' empire fragrance  ',
#  ' kristiansand new york  ',
#  ' pierre bourdon  ',
#  ' bésame cosmetics  ',
#  ' egofacto  ',
#  ' comptoir cologne  ',
#  ' erboristeria magentina  ',
#  ' flormar  ',
#  ' calypso st. barth  ',
#  ' roger & gallet  ',
#  ' dilis parfum  ',
#  ' ottaniqo  ',
#  ' joan rivers  ',
#  ' fubu  ',
#  ' frazer parfum  ',
#  ' anima mundi  ',
#  ' linn young  ',
#  ' baratti  ',
#  ' eau jeune  ',
#  ' nelly  ',
#  ' clinique  ',
#  ' paulina rubio  ',
#  ' lanvin  ',
#  ' lubin  ',
#  ' cacharel  ',
#  ' alessandro della torre  ',
#  ' jacob  ',
#  ' king`s palace perfumery  ',
#  ' santa eulalia  ',
#  ' aromachology  ',
#  ' ex idolo  ',
#  ' truly yours parfums  ',
#  ' galerie noemie  ',
#  ' pure gold perfumes  ',
#  ' lyn  ',
#  ' anatole lebreton  ',
#  ' creso  ',
#  ' roxy  ',
#  ' ashley roberts  ',
#  ' lanoe  ',
#  ' mekkanische rose  ',
#  ' tulisa contostavlos  ',
#  ' montegrappa  ',
#  ' la parfumerie arlesienne  ',
#  ' bruno fazzolari  ',
#  ' catherine malandrino  ',
#  ' guess  ',
#  ' richard james  ',
#  ' star nature  ',
#  ' the gate fragrances paris  ',
#  ' boudicca  ',
#  ' afnan perfumes  ',
#  ' heno de pravia  ',
#  ' jasper conran  ',
#  ' sunny leone  ',
#  ' florascent  ',
#  ' michael storer  ',
#  ' la sultane de saba  ',
#  ' amado  ',
#  ' eddie bauer  ',
#  ' voronoi  ',
#  ' accord parfait  ',
#  ' bois 1920  ',
#  ' enrico coveri  ',
#  ' haeckels  ',
#  ' eon productions  ',
#  ' parera  ',
#  ' popy moreni  ',
#  ' jack perfume  ',
#  ' jennifer aniston  ',
#  ' david thibaud-bourahla  ',
#  ' wittchen  ',
#  ' ella mikao  ',
#  ' oilily  ',
#  ' marina spadafora  ',
#  ' nina ricci  ',
#  ' donna karan  ',
#  ' fleurage  ',
#  ' succes de paris  ',
#  ' kenji tanaka  ',
#  ' parfums de coeur  ',
#  ' pacoma  ',
#  ' pmp perfumes mayr plettenberg  ',
#  ' michael michalsky  ',
#  ' tiffi  ',
#  ' ana salazar  ',
#  ' amygdala  ',
#  ' nateeva  ',
#  ' cult of scent  ',
#  ' hawaiian tropic  ',
#  ' croatian perfume house  ',
#  ' massimo dutti  ',
#  ' tom tailor  ',
#  ' twiggy  ',
#  ' pal zileri  ',
#  ' blocki perfumes  ',
#  ' cerchi nell’acqua  ',
#  ' maison martin margiela  ',
#  ' american beauty  ',
#  ' burt`s bees  ',
#  ' shania twain  ',
#  ' teana  ',
#  ' chabaud maison de parfum  ',
#  ' diane von furstenberg  ',
#  ' christian richard  ',
#  ' cesare paciotti  ',
#  ' jehanne rigaud parfums  ',
#  ' judith  ',
#  ' i coloniali  ',
#  ' flamboyant  ',
#  ' seventeen  ',
#  ' cafe parfums  ',
#  ' shulton company  ',
#  ' edgardio chilini  ',
#  ' pomellato  ',
#  ' desigual  ',
#  ' rpl  ',
#  ' natalie  ',
#  ' homoelegans  ',
#  ' memo paris  ',
#  ' jammie nicholas  ',
#  ' acque di italia  ',
#  ' maison de parfum berry  ',
#  ' sevigne  ',
#  ' affinessence  ',
#  ' mojo  ',
#  ' sandalia  ',
#  ' barneys new york  ',
#  ' ellen tracy  ',
#  ' helène d`arcy  ',
#  ' juliette has a gun  ',
#  ' the scented souq  ',
#  ' van gils  ',
#  ' les fleurs de bach  ',
#  ' the federation of bakers  ',
#  ' byblos  ',
#  ' a dozen roses  ',
#  ' nature`s  ',
#  ' kuumba made  ',
#  ' gin tonic  ',
#  ' dominican perfumes  ',
#  ' ventilo  ',
#  ' gydja  ',
#  ' atelier ulric fragrances  ',
#  ' cffc fragrances  ',
#  ' le labo  ',
#  ' next  ',
#  ' v canto  ',
#  ' northfields tailors  ',
#  ' evterpa  ',
#  ' marc cain  ',
#  ' pitbull  ',
#  ' undergreen  ',
#  ' fueguia 1833  ',
#  ' coquillete  ',
#  ' verduu  ',
#  ' aziza world fragrances  ',
#  ' fernanda brandao  ',
#  ' natura siberica  ',
#  ' nomaterra  ',
#  ' raunsborg  ',
#  ' triquetra  ',
#  ' glamour & heels  ',
#  ' agatha paris  ',
#  ' tremendous  ',
#  ' selena gomez  ',
#  ' dermika  ',
#  ' thierry blondeau  ',
#  ' laubahn perfumes  ',
#  ' loriblu  ',
#  ' nafnaf  ',
#  ' raw spirit fragrances  ',
#  ' justice bodan  ',
#  ' quem disse berenice  ',
#  ' panier des sens  ',
#  ' schiaparelli  ',
#  ' derek lam 10 crosby  ',
#  ' vivienne sabo  ',
#  ' alliance  ',
#  ' ruik  ',
#  ' khalis  ',
#  ' la maison de la vanille  ',
#  ' eolie parfums  ',
#  ' space nk  ',
#  ' beaufort london  ',
#  ' royal copenhagen  ',
#  ' anthony logistics  ',
#  ' jar parfums  ',
#  ' moschino  ',
#  ' shilpa shetty  ',
#  ' adidas  ',
#  ' christian louboutin  ',
#  ' honore payan  ',
#  ' hrh princess elizabeth  ',
#  ' compagnie royale  ',
#  ' aquaflor firenze  ',
#  ' pino silvestre  ',
#  ' fifi chachnil  ',
#  ' francois deli  ',
#  ' note di profumum  ',
#  ' the scent of departure  ',
#  ' john varvatos  ',
#  ' zorica of malibu  ',
#  ' outremer  ',
#  ' autre parfum  ',
#  ' fumparfum  ',
#  ' monoscent  ',
#  ' solinotes  ',
#  ' daniel barros  ',
#  ' mar de ibiza  ',
#  ' jul et mad paris  ',
#  ' parfums bdk paris  ',
#  ' happ & stahns  ',
#  ' inubi  ',
#  ' profumi di pantelleria  ',
#  ' francesca dell`oro  ',
#  ' the fragrance kitchen  ',
#  ' tommy hilfiger  ',
#  ' tayyib  ',
#  ' faconnable  ',
#  ' nyakio  ',
#  ' valentino  ',
#  ' elanzia  ',
#  ' jean-michel duriez  ',
#  ' bottega veneta  ',
#  ' dina cosmetics  ',
#  ' mango  ',
#  ' nomenclature  ',
#  ' yeye parfums  ',
#  ' menard  ',
#  ' michael jordan  ',
#  ' monastyrskiy sad  ',
#  ' harley davidson  ',
#  ' michal szulc  ',
#  ' sfumato  ',
#  ' herr von eden  ',
#  ' amouroud  ',
#  ' nicki minaj  ',
#  ' carven  ',
#  ' tom daxon  ',
#  ' violin fragrance  ',
#  ' oribe  ',
#  ' mendittorosa  ',
#  ' liv grn  ',
#  ' fitzgerald and guislain  ',
#  ' sebastiane  ',
#  ' nicolai parfumeur createur  ',
#  ' soap & glory  ',
#  ' adopt` by reserve naturelle  ',
#  ' lady gaga  ',
#  ' mtv perfumes  ',
#  " l'adoné  ",
#  ' orsay  ',
#  ' aisha perfumes by neide albano  ',
#  ' dl & co  ',
#  ' la rive  ',
#  ' bond no 9  ',
#  ' bourjois  ',
#  ' l`wren scott  ',
#  ' maryaj  ',
#  ' everlast  ',
#  ' fossil  ',
#  ' tania bulhões  ',
#  ' viva creation  ',
#  ' shiara  ',
#  ' art meets art  ',
#  ' artemis of switzerland   ',
#  ' carthusia  ',
#  ' tim mcgraw  ',
#  ' regina schrecker  ',
#  ' victor  ',
#  ' a lab on fire  ',
#  ' na nin  ',
#  ' acqua di portofino  ',
#  ' thymes  ',
#  ' divona  ',
#  ' decleor  ',
#  ' place des lices  ',
#  ' arshia parfums  ',
#  ' estiara  ',
#  ' esse strikes the notes  ',
#  ' judith leiber  ',
#  ' deco london  ',
#  ' marcella wouters  ',
#  ' serge louis alvarez  ',
#  ' nina`s nature  ',
#  ' blackglama  ',
#  ' fresh  ',
#  ' germaine monteil  ',
#  ' parfums constantine  ',
#  ' profumum roma  ',
#  ' rouge bunny rouge  ',
#  ' pokrovka trading house  ',
#  ' trisha yearwood  ',
#  ' oriza l. legrand  ',
#  ' stenders  ',
#  ' cosmogony  ',
#  ' mary chess  ',
#  ' sjaak hullekes  ',
#  ' refan  ',
#  ' orali perfume  ',
#  ' essential faith  ',
#  ' disney jasmine collection by sephora  ',
#  ' christine lavoisier parfums  ',
#  ' le chameau  ',
#  ' lancome  ',
#  ' bastide aix en provence  ',
#  ' gri gri parfums  ',
#  ' fragrance republic  ',
#  ' mary kay  ',
#  ' elemis  ',
#  ' black up  ',
#  ' lentheric  ',
#  ' natur milano  ',
#  ' parfum d`empire  ',
#  ' barbour  ',
#  ' johan b  ',
#  ' swiss alpine  ',
#  ' esprit  ',
#  ' salvador dali  ',
#  ' alfred dunhill  ',
#  ' mihail voronin  ',
#  ' oscar de la renta  ',
#  ' horseball  ',
#  ' parli parfum  ',
#  ' florame  ',
#  ' apothia  ',
#  ' fleur fragrance  ',
#  ' zuma  ',
#  ' danny seo  ',
#  ' bodevoke  ',
#  ' long lost perfume  ',
#  ' juniper ridge  ',
#  ' michel klein  ',
#  ...]

# %%
len(matched)
# Out:
# 3189

# %%
v2 = matched + list(v1) # смэтченные и несмэтченные

# %%
len(v2)
# Out:
# 3423
